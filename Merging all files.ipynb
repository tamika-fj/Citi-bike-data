# %%
import pandas as pd
import glob
from pathlib import Path

# %%
# Create a list of CSV file paths to combine
file_paths = glob.glob("Files/*.csv")

# %%
# Initialize an empty list to store DataFrames
dataframes = []

# %%
# Read each CSV file into a DataFrame and append it to the list
for file_path in file_paths:
    try:
        df = pd.read_csv(file_path)
        dataframes.append(df)
    except pd.errors.EmptyDataError:
        print(f"Warning: Empty file found at {file_path}")
    except pd.errors.ParserError as e:
        print(f"Error reading file {file_path}: {str(e)}")

# %%
# Check if there are valid DataFrames to concatenate
if dataframes:
    # Concatenate all DataFrames into one
    all_combined_df = pd.concat(dataframes, ignore_index=True)
    
    # Save the combined DataFrame to a new CSV file
    all_combined_df.to_csv('all_combined_data.csv', index=False)
else:
    print("No valid DataFrames to concatenate.")

# %%
# Concatenate all DataFrames into one
combined_new_files_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_new_files_df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        121DD7DD23CB1335    docked_bike  2021-02-03 23:11:28
# 1        FD73FB85F008349D    docked_bike  2021-02-27 16:34:05
# 2        39F9E6663CB5FDF6    docked_bike  2021-02-26 23:16:04
# 3        A64745CB0792EC6F    docked_bike  2021-02-24 16:51:50
# 4        75CC76EB9543764A    docked_bike  2021-02-24 20:44:16
# ...                   ...            ...                  ...
# 2078980  944F5CD711E7688E   classic_bike  2023-07-25 18:21:52
# 2078981  4665B542F79F8C43  electric_bike  2023-07-26 22:22:20
# 2078982  789D45FDEBC19E83   classic_bike  2023-07-31 07:57:29
# 2078983  FFBE463288D36C2A   classic_bike  2023-07-07 17:52:09
# 2078984  4DACECF4EBBEB60C   classic_bike  2023-07-26 20:54:16
#
#                     ended_at          start_station_name start_station_id  \
# 0        2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1        2021-02-27 16:56:40                Newport Pkwy            JC008
# 2        2021-02-26 23:22:25              Journal Square            JC103
# 3        2021-02-24 17:16:09  Hoboken Ave at Monmouth St            JC105
# 4        2021-02-24 20:44:46  Hoboken Ave at Monmouth St            JC105
# ...                      ...                         ...              ...
# 2078980  2023-07-25 18:34:38              Van Vorst Park            JC035
# 2078981  2023-07-26 22:26:20              Van Vorst Park            JC035
# 2078982  2023-07-31 08:03:58              Van Vorst Park            JC035
# 2078983  2023-07-07 18:00:14              Van Vorst Park            JC035
# 2078984  2023-07-26 21:05:33              Van Vorst Park            JC035
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                   Christ Hospital          JC034  40.735208 -74.046964
# 1                  Marin Light Rail          JC013  40.728744 -74.032108
# 2             Baldwin at Montgomery          JC020  40.733670 -74.062500
# 3        Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# 4        Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# ...                             ...            ...        ...        ...
# 2078980                Newport Pkwy          JC008  40.718489 -74.047727
# 2078981                   Warren St          JC006  40.718489 -74.047727
# 2078982                Newport Pkwy          JC008  40.718422 -74.047691
# 2078983                   Warren St          JC006  40.718489 -74.047727
# 2078984                Newport Pkwy          JC008  40.718489 -74.047727
#
#            end_lat    end_lng member_casual
# 0        40.734786 -74.050444        member
# 1        40.714584 -74.042817        member
# 2        40.723659 -74.064194        member
# 3        40.735208 -74.046964        casual
# 4        40.735208 -74.046964        member
# ...            ...        ...           ...
# 2078980  40.728745 -74.032108        member
# 2078981  40.721124 -74.038051        member
# 2078982  40.728745 -74.032108        member
# 2078983  40.721124 -74.038051        member
# 2078984  40.728745 -74.032108        member
#
# [2078985 rows x 13 columns]

# %%
cleaned_combined_new = combined_new_files_df.drop(columns=['ride_id', 'rideable_type'])
cleaned_combined_new.head()
# Out:
#             started_at             ended_at          start_station_name  \
# 0  2021-02-03 23:11:28  2021-02-03 23:18:28  Hoboken Ave at Monmouth St
# 1  2021-02-27 16:34:05  2021-02-27 16:56:40                Newport Pkwy
# 2  2021-02-26 23:16:04  2021-02-26 23:22:25              Journal Square
# 3  2021-02-24 16:51:50  2021-02-24 17:16:09  Hoboken Ave at Monmouth St
# 4  2021-02-24 20:44:16  2021-02-24 20:44:46  Hoboken Ave at Monmouth St
#
#   start_station_id            end_station_name end_station_id  start_lat  \
# 0            JC105             Christ Hospital          JC034  40.735208
# 1            JC008            Marin Light Rail          JC013  40.728744
# 2            JC103       Baldwin at Montgomery          JC020  40.733670
# 3            JC105  Hoboken Ave at Monmouth St          JC105  40.735208
# 4            JC105  Hoboken Ave at Monmouth St          JC105  40.735208
#
#    start_lng    end_lat    end_lng member_casual
# 0 -74.046964  40.734786 -74.050444        member
# 1 -74.032108  40.714584 -74.042817        member
# 2 -74.062500  40.723659 -74.064194        member
# 3 -74.046963  40.735208 -74.046964        casual
# 4 -74.046963  40.735208 -74.046964        member

# %%
cleaned_new = cleaned_combined_new

# %%
cleaned_new['started_at'] = pd.to_datetime(cleaned_new['started_at'],
                                                format='%Y-%m-%d %H:%M:%S.%f')
cleaned_new['ended_at'] = pd.to_datetime(cleaned_new['ended_at'],
                                                format='%Y-%m-%d %H:%M:%S.%f')

# %%
cleaned_new
# Out:
#                  started_at            ended_at          start_station_name  \
# 0       2021-02-03 23:11:28 2021-02-03 23:18:28  Hoboken Ave at Monmouth St
# 1       2021-02-27 16:34:05 2021-02-27 16:56:40                Newport Pkwy
# 2       2021-02-26 23:16:04 2021-02-26 23:22:25              Journal Square
# 3       2021-02-24 16:51:50 2021-02-24 17:16:09  Hoboken Ave at Monmouth St
# 4       2021-02-24 20:44:16 2021-02-24 20:44:46  Hoboken Ave at Monmouth St
# ...                     ...                 ...                         ...
# 2078980 2023-07-25 18:21:52 2023-07-25 18:34:38              Van Vorst Park
# 2078981 2023-07-26 22:22:20 2023-07-26 22:26:20              Van Vorst Park
# 2078982 2023-07-31 07:57:29 2023-07-31 08:03:58              Van Vorst Park
# 2078983 2023-07-07 17:52:09 2023-07-07 18:00:14              Van Vorst Park
# 2078984 2023-07-26 20:54:16 2023-07-26 21:05:33              Van Vorst Park
#
#         start_station_id            end_station_name end_station_id  \
# 0                  JC105             Christ Hospital          JC034
# 1                  JC008            Marin Light Rail          JC013
# 2                  JC103       Baldwin at Montgomery          JC020
# 3                  JC105  Hoboken Ave at Monmouth St          JC105
# 4                  JC105  Hoboken Ave at Monmouth St          JC105
# ...                  ...                         ...            ...
# 2078980            JC035                Newport Pkwy          JC008
# 2078981            JC035                   Warren St          JC006
# 2078982            JC035                Newport Pkwy          JC008
# 2078983            JC035                   Warren St          JC006
# 2078984            JC035                Newport Pkwy          JC008
#
#          start_lat  start_lng    end_lat    end_lng member_casual
# 0        40.735208 -74.046964  40.734786 -74.050444        member
# 1        40.728744 -74.032108  40.714584 -74.042817        member
# 2        40.733670 -74.062500  40.723659 -74.064194        member
# 3        40.735208 -74.046963  40.735208 -74.046964        casual
# 4        40.735208 -74.046963  40.735208 -74.046964        member
# ...            ...        ...        ...        ...           ...
# 2078980  40.718489 -74.047727  40.728745 -74.032108        member
# 2078981  40.718489 -74.047727  40.721124 -74.038051        member
# 2078982  40.718422 -74.047691  40.728745 -74.032108        member
# 2078983  40.718489 -74.047727  40.721124 -74.038051        member
# 2078984  40.718489 -74.047727  40.728745 -74.032108        member
#
# [2078985 rows x 11 columns]

# %%
#create path to old csv file:
old_data= Path("Resources/merged_old.csv")
old_data_df=pd.read_csv(old_data)

# %%
old_data_df
# Out:
#                      started_at                 ended_at  \
# 0       2020-07-01 00:23:19.822  2020-07-01 01:02:13.298
# 1       2020-07-01 00:27:45.242  2020-07-01 00:47:49.196
# 2       2020-07-01 00:34:17.868  2020-07-01 00:47:24.631
# 3       2020-07-01 00:51:07.531  2020-07-01 01:15:56.020
# 4       2020-07-01 00:51:16.388  2020-07-01 01:35:58.459
# ...                         ...                      ...
# 210454  2021-01-31 20:16:05.470  2021-01-31 20:57:22.011
# 210455  2021-01-31 21:05:05.209  2021-01-31 21:07:32.866
# 210456  2021-01-31 21:06:23.588  2021-01-31 21:17:23.842
# 210457  2021-01-31 21:16:37.822  2021-01-31 21:23:02.124
# 210458  2021-01-31 23:24:50.881  2021-01-31 23:30:47.303
#
#                 start_station_name  start_lat  start_lng  \
# 0                   Jackson Square  40.711130 -74.078900
# 1       Hoboken Ave at Monmouth St  40.735208 -74.046964
# 2       Columbus Dr at Exchange Pl  40.716870 -74.032810
# 3                     Glenwood Ave  40.727551 -74.071061
# 4                         Union St  40.718211 -74.083639
# ...                            ...        ...        ...
# 210454                   Warren St  40.721124 -74.038051
# 210455               Grove St PATH  40.719586 -74.043117
# 210456                  Newark Ave  40.721525 -74.046305
# 210457           JC Medical Center  40.716540 -74.049638
# 210458                  Harborside  40.719252 -74.034234
#
#              end_station_name    end_lat    end_lng member_casual
# 0            Marin Light Rail  40.714584 -74.042817        casual
# 1                Newport PATH  40.727224 -74.033759        member
# 2       Baldwin at Montgomery  40.723659 -74.064194        member
# 3             McGinley Square  40.725340 -74.067622        member
# 4                Lincoln Park  40.724605 -74.078406        member
# ...                       ...        ...        ...           ...
# 210454          Montgomery St  40.719420 -74.050990        member
# 210455              Warren St  40.721124 -74.038051        member
# 210456       Marin Light Rail  40.714584 -74.042817        member
# 210457         Lafayette Park  40.713464 -74.062859        member
# 210458          Grove St PATH  40.719586 -74.043117        member
#
# [210459 rows x 9 columns]

# %%
# Merge the old and new dataframes 
all_merged = pd.concat([cleaned_new, old_data_df], ignore_index=True)

# %%
all_merged
# Out:
#                       started_at                 ended_at  \
# 0            2021-02-03 23:11:28      2021-02-03 23:18:28
# 1            2021-02-27 16:34:05      2021-02-27 16:56:40
# 2            2021-02-26 23:16:04      2021-02-26 23:22:25
# 3            2021-02-24 16:51:50      2021-02-24 17:16:09
# 4            2021-02-24 20:44:16      2021-02-24 20:44:46
# ...                          ...                      ...
# 2289439  2021-01-31 20:16:05.470  2021-01-31 20:57:22.011
# 2289440  2021-01-31 21:05:05.209  2021-01-31 21:07:32.866
# 2289441  2021-01-31 21:06:23.588  2021-01-31 21:17:23.842
# 2289442  2021-01-31 21:16:37.822  2021-01-31 21:23:02.124
# 2289443  2021-01-31 23:24:50.881  2021-01-31 23:30:47.303
#
#                  start_station_name start_station_id  \
# 0        Hoboken Ave at Monmouth St            JC105
# 1                      Newport Pkwy            JC008
# 2                    Journal Square            JC103
# 3        Hoboken Ave at Monmouth St            JC105
# 4        Hoboken Ave at Monmouth St            JC105
# ...                             ...              ...
# 2289439                   Warren St              NaN
# 2289440               Grove St PATH              NaN
# 2289441                  Newark Ave              NaN
# 2289442           JC Medical Center              NaN
# 2289443                  Harborside              NaN
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                   Christ Hospital          JC034  40.735208 -74.046964
# 1                  Marin Light Rail          JC013  40.728744 -74.032108
# 2             Baldwin at Montgomery          JC020  40.733670 -74.062500
# 3        Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# 4        Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# ...                             ...            ...        ...        ...
# 2289439               Montgomery St            NaN  40.721124 -74.038051
# 2289440                   Warren St            NaN  40.719586 -74.043117
# 2289441            Marin Light Rail            NaN  40.721525 -74.046305
# 2289442              Lafayette Park            NaN  40.716540 -74.049638
# 2289443               Grove St PATH            NaN  40.719252 -74.034234
#
#            end_lat    end_lng member_casual
# 0        40.734786 -74.050444        member
# 1        40.714584 -74.042817        member
# 2        40.723659 -74.064194        member
# 3        40.735208 -74.046964        casual
# 4        40.735208 -74.046964        member
# ...            ...        ...           ...
# 2289439  40.719420 -74.050990        member
# 2289440  40.721124 -74.038051        member
# 2289441  40.714584 -74.042817        member
# 2289442  40.713464 -74.062859        member
# 2289443  40.719586 -74.043117        member
#
# [2289444 rows x 11 columns]

# %%
all_merged['trip_id'] = all_merged.index
all_merged
# Out:
#                       started_at                 ended_at  \
# 0            2021-02-03 23:11:28      2021-02-03 23:18:28
# 1            2021-02-27 16:34:05      2021-02-27 16:56:40
# 2            2021-02-26 23:16:04      2021-02-26 23:22:25
# 3            2021-02-24 16:51:50      2021-02-24 17:16:09
# 4            2021-02-24 20:44:16      2021-02-24 20:44:46
# ...                          ...                      ...
# 2289439  2021-01-31 20:16:05.470  2021-01-31 20:57:22.011
# 2289440  2021-01-31 21:05:05.209  2021-01-31 21:07:32.866
# 2289441  2021-01-31 21:06:23.588  2021-01-31 21:17:23.842
# 2289442  2021-01-31 21:16:37.822  2021-01-31 21:23:02.124
# 2289443  2021-01-31 23:24:50.881  2021-01-31 23:30:47.303
#
#                  start_station_name start_station_id  \
# 0        Hoboken Ave at Monmouth St            JC105
# 1                      Newport Pkwy            JC008
# 2                    Journal Square            JC103
# 3        Hoboken Ave at Monmouth St            JC105
# 4        Hoboken Ave at Monmouth St            JC105
# ...                             ...              ...
# 2289439                   Warren St              NaN
# 2289440               Grove St PATH              NaN
# 2289441                  Newark Ave              NaN
# 2289442           JC Medical Center              NaN
# 2289443                  Harborside              NaN
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                   Christ Hospital          JC034  40.735208 -74.046964
# 1                  Marin Light Rail          JC013  40.728744 -74.032108
# 2             Baldwin at Montgomery          JC020  40.733670 -74.062500
# 3        Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# 4        Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# ...                             ...            ...        ...        ...
# 2289439               Montgomery St            NaN  40.721124 -74.038051
# 2289440                   Warren St            NaN  40.719586 -74.043117
# 2289441            Marin Light Rail            NaN  40.721525 -74.046305
# 2289442              Lafayette Park            NaN  40.716540 -74.049638
# 2289443               Grove St PATH            NaN  40.719252 -74.034234
#
#            end_lat    end_lng member_casual  trip_id
# 0        40.734786 -74.050444        member        0
# 1        40.714584 -74.042817        member        1
# 2        40.723659 -74.064194        member        2
# 3        40.735208 -74.046964        casual        3
# 4        40.735208 -74.046964        member        4
# ...            ...        ...           ...      ...
# 2289439  40.719420 -74.050990        member  2289439
# 2289440  40.721124 -74.038051        member  2289440
# 2289441  40.714584 -74.042817        member  2289441
# 2289442  40.713464 -74.062859        member  2289442
# 2289443  40.719586 -74.043117        member  2289443
#
# [2289444 rows x 12 columns]

# %%
#drop null values and reset index
all_merged_cleaned = all_merged.dropna()
all_merged_cleaned = all_merged_cleaned.reset_index(drop=True)
all_merged_cleaned
# Out:
#                   started_at             ended_at          start_station_name  \
# 0        2021-02-03 23:11:28  2021-02-03 23:18:28  Hoboken Ave at Monmouth St
# 1        2021-02-27 16:34:05  2021-02-27 16:56:40                Newport Pkwy
# 2        2021-02-26 23:16:04  2021-02-26 23:22:25              Journal Square
# 3        2021-02-24 16:51:50  2021-02-24 17:16:09  Hoboken Ave at Monmouth St
# 4        2021-02-24 20:44:16  2021-02-24 20:44:46  Hoboken Ave at Monmouth St
# ...                      ...                  ...                         ...
# 2070492  2023-07-25 18:21:52  2023-07-25 18:34:38              Van Vorst Park
# 2070493  2023-07-26 22:22:20  2023-07-26 22:26:20              Van Vorst Park
# 2070494  2023-07-31 07:57:29  2023-07-31 08:03:58              Van Vorst Park
# 2070495  2023-07-07 17:52:09  2023-07-07 18:00:14              Van Vorst Park
# 2070496  2023-07-26 20:54:16  2023-07-26 21:05:33              Van Vorst Park
#
#         start_station_id            end_station_name end_station_id  \
# 0                  JC105             Christ Hospital          JC034
# 1                  JC008            Marin Light Rail          JC013
# 2                  JC103       Baldwin at Montgomery          JC020
# 3                  JC105  Hoboken Ave at Monmouth St          JC105
# 4                  JC105  Hoboken Ave at Monmouth St          JC105
# ...                  ...                         ...            ...
# 2070492            JC035                Newport Pkwy          JC008
# 2070493            JC035                   Warren St          JC006
# 2070494            JC035                Newport Pkwy          JC008
# 2070495            JC035                   Warren St          JC006
# 2070496            JC035                Newport Pkwy          JC008
#
#          start_lat  start_lng    end_lat    end_lng member_casual
# 0        40.735208 -74.046964  40.734786 -74.050444        member
# 1        40.728744 -74.032108  40.714584 -74.042817        member
# 2        40.733670 -74.062500  40.723659 -74.064194        member
# 3        40.735208 -74.046963  40.735208 -74.046964        casual
# 4        40.735208 -74.046963  40.735208 -74.046964        member
# ...            ...        ...        ...        ...           ...
# 2070492  40.718489 -74.047727  40.728745 -74.032108        member
# 2070493  40.718489 -74.047727  40.721124 -74.038051        member
# 2070494  40.718422 -74.047691  40.728745 -74.032108        member
# 2070495  40.718489 -74.047727  40.721124 -74.038051        member
# 2070496  40.718489 -74.047727  40.728745 -74.032108        member
#
# [2070497 rows x 11 columns]

# %%
# Write the merged data to CSV
output_file_path= Path('Resources\merged_citi_files.csv') 
all_merged.to_csv(output_file_path, index=False)
